# %% [markdown]
# import numpy as np
# import matplotlib.pyplot as plt

# %%
np.x = [4, 4.1, 4.2, 4.3]
np.y = [ -3100.51190282, -3100.54572391, -3100.54879324, -3100.53026913]

# %%
plt.plot(np.x,np.y)
#plt.show()
plt.tight_layout()
